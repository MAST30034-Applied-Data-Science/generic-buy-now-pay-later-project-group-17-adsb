# %%
import pandas as pd

# %%
data_path = "../data/curated/merged_transactions.parquet"
data = pd.read_parquet(data_path)
data.head()
# Out:
#    user_id  merchant_abn  dollar_value                              order_id  \
# 0        1   28000487688    133.226894  0c37b3f7-c7f1-48cb-bcc7-0a58e76608ea
# 1    20864   28000487688    378.937918  f7eca4c5-474b-4ab2-ad61-6a8219b26d67
# 2    22666   28000487688    108.164737  f93ae993-80eb-42d1-aaa6-3659e759ed87
# 3    23228   28000487688    329.178020  2a61a2f3-fbca-4011-87a3-6f45b4f1f7ed
# 4     5131   28000487688    425.750157  b0b4b456-e286-4b84-8313-f5c7210c7b4b
#
#   order_datetime        merchant_name  \
# 0     2021-02-28  Sed Nunc Industries
# 1     2021-02-28  Sed Nunc Industries
# 2     2021-02-28  Sed Nunc Industries
# 3     2021-02-28  Sed Nunc Industries
# 4     2021-02-28  Sed Nunc Industries
#
#                                                 tags  \
# 0  ((books, periodicals, anD newspapers), (b), (t...
# 1  ((books, periodicals, anD newspapers), (b), (t...
# 2  ((books, periodicals, anD newspapers), (b), (t...
# ...

# %%
data["sector_tags"].value_counts()
# Out:
# tent and awning shops                                                                    1771141
# gift, card, novelty, and souvenir shops                                                  1586534
# digital goods: books, movies, music                                                      1240476
# watch, clock, and jewelry repair shops                                                    998140
# cable, satellite, and other pay television and radio services                             925853
# florists supplies, nursery stock, and flowers                                             852780
# opticians, optical goods, and eyeglasses                                                  809177
# computers, computer peripheral equipment, and software                                    694109
# computer programming , data processing, and integrated systems design services            500805
# furniture, home furnishings and equipment shops, and manufacturers, except appliances     481065
# ...

# %% [markdown]
# https://www.citibank.com/tts/solutions/commercial-cards/assets/docs/govt/Merchant-Category-Codes.pdf

# %% [markdown]
# Miscellaneous Stores: tent and awning shops; Card, Gift, Novelty and Souvenir Shops; digital goods: books, movies, music; watch, clock, and jewelry repair shops; furniture, home furnishings and equipment shops, and manufacturers, except appliances; artist supply and craft shops; music shops - musical instruments, pianos, and sheet music; health and beauty spas; hobby, toy and game shops; bicycle shops - sales and service; Antique Shops–Sales, Repairs and Restoration Services; Art Dealers and Galleries; jewelry, watch, clock, and silverware shops

# %% [markdown]
# Utility services: cable, satellite, and other pay television and radio services; telecom

# %% [markdown]
# Retail outlet services: florists supplies, nursery stock, and flowers; Computers, Computer Peripheral Equipment, and Software; Books, Periodicals and Newspapers; lawn and garden supply outlets, including nurseries; motor vehicle supplies and new parts; stationery, office supplies and printing and writing paper

# %% [markdown]
# Professional services and membership organisations: opticians, optical goods, and eyeglasses

# %% [markdown]
# Business Services: computer programming , data processing, and integrated systems design services; equipment, tool, furniture, and appliance rent al and leasing

# %% [markdown]
# Clothing stores: shoe shops

# %% [markdown]
# We roll clothing stores into retail outlet services to make 5 distinct merchant groupings
