# %%
import pandas as pd

# %%
data_path = "../data/curated/transactions.parquet"
data = pd.read_parquet(data_path)
data.head()
# Out:
#    user_id  merchant_abn  dollar_value                              order_id  \
# 0        1   28000487688    133.226894  0c37b3f7-c7f1-48cb-bcc7-0a58e76608ea
# 1    20864   28000487688    378.937918  f7eca4c5-474b-4ab2-ad61-6a8219b26d67
# 2    22666   28000487688    108.164737  f93ae993-80eb-42d1-aaa6-3659e759ed87
# 3    23228   28000487688    329.178020  2a61a2f3-fbca-4011-87a3-6f45b4f1f7ed
# 4     5131   28000487688    425.750157  b0b4b456-e286-4b84-8313-f5c7210c7b4b
#
#   order_datetime        merchant_name  \
# 0     2021-02-28  Sed Nunc Industries
# 1     2021-02-28  Sed Nunc Industries
# 2     2021-02-28  Sed Nunc Industries
# 3     2021-02-28  Sed Nunc Industries
# 4     2021-02-28  Sed Nunc Industries
#
#                                                 tags  \
# 0  ((books, periodicals, anD newspapers), (b), (t...
# 1  ((books, periodicals, anD newspapers), (b), (t...
# 2  ((books, periodicals, anD newspapers), (b), (t...
# ...

# %%
data.sample(n=10)
# Out:
#           user_id  merchant_abn  dollar_value  \
# 6590594     20391   22206721435    122.654287
# 1684690     17476   24852446429      9.466270
# 7668473     19764   35016722348      4.847609
# 13315626      132   92636306985    141.898408
# 12716198    17995   82786382916     98.325859
# 1360996      9713   89640578182     53.986055
# 1036199      6968   57900494384      1.672879
# 12297924      661   76819856970    892.125446
# 11017988    15885   68699143999     57.696875
# 9581305      4459   24938000144      6.413679
#
#                                       order_id order_datetime  \
# 6590594   733ce265-a220-4cea-a24d-5090b13b24c2     2021-07-19
# 1684690   feab900c-89e8-4a99-a2e4-c093d9a02e55     2021-12-22
# 7668473   511dabd2-fa2a-4d69-bba0-dd807c4d1206     2022-01-04
# 13315626  243789bf-4f1b-4cf9-9d5e-912276e13dfd     2021-11-26
# 12716198  f29660cd-964e-4797-af21-b37d1dd974f5     2021-11-23
# 1360996   7c356164-3758-47b6-bb52-2d9997ecea78     2022-09-18
# ...

# %%
data.count()
# Out:
# user_id           13171143
# merchant_abn      13171143
# dollar_value      13171143
# order_id          13171143
# order_datetime    13171143
# merchant_name     13171143
# tags              13171143
# sector_tags       13171143
# revenue_band      13171143
# take_rate         13171143
# consumer_name     13171143
# state             13171143
# postcode          13171143
# gender            13171143
# dtype: int64

# %%
data[data.isna().any(axis=1)]
# Out:
# Empty DataFrame
# Columns: [user_id, merchant_abn, dollar_value, order_id, order_datetime, merchant_name, tags, sector_tags, revenue_band, take_rate, consumer_name, state, postcode, gender]
# Index: []
